# %% [markdown]
# ![logistic_regression.JPG](attachment:logistic_regression.JPG)

# %% [markdown]
# please refer to the Train.ipnb for details about the data

# %% [markdown]
# ## Exploratory Data Analysis Of Test Data

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %%
test=pd.read_csv("Churn_Test.csv")

# %%
test.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0      10001    15798485    Copley          565     Bolga    Male   31
# 1      10002    15588959     T'ang          569     Bolga    Male   34
# 2      10003    15624896        Ku          669     Bolga  Female   20
# 3      10004    15639629  McConnan          694     Bolga    Male   39
# 4      10005    15638852     Ts'ui          504     Accra    Male   28
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       1       0.00              1          0               1
# 1       4       0.00              1          0               1
# 2       7       0.00              2          1               0
# 3       4  173255.48              1          1               1
# 4      10  109291.36              1          1               1
#
#    EstimatedSalary  Exited
# 0         20443.08       0
# 1          4045.90       0
# 2        128838.67       0
# 3         81293.10       0
# 4        187593.15       0

# %% [markdown]
# we want to check whether our data has null value. So we visualize the data

# %%
sns.heatmap(test.isnull(),yticklabels=False,cbar=False,cmap="viridis")

# %% [markdown]
# ## We want to also have a basic overview of the number of people who have exited the bank and the number that hasn't

# %% [markdown]
# ### By Gender

# %%
sns.set_style("whitegrid")
sns.countplot(x="Exited",hue="Gender",data=test, palette="RdBu_r")

# %% [markdown]
# ### By Geography

# %%
sns.countplot(x="Exited",hue="Geography",data=test)

# %% [markdown]
# ### By Whether or not they have credit card

# %%
sns.countplot(x="Exited",hue="HasCrCard",data=test)

# %% [markdown]
# ### We want to also know the distribution of ages of our customer

# %%
sns.distplot(test["Age"],kde=False,bins=30)

# %%
test.info
# Out:
# <bound method DataFrame.info of      RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0        10001    15798485     Copley          565     Bolga    Male   31
# 1        10002    15588959      T'ang          569     Bolga    Male   34
# 2        10003    15624896         Ku          669     Bolga  Female   20
# 3        10004    15639629   McConnan          694     Bolga    Male   39
# 4        10005    15638852      Ts'ui          504     Accra    Male   28
# ..         ...         ...        ...          ...       ...     ...  ...
# 995      10996    15730373     Starks          531     Bolga  Female   34
# 996      10997    15716191      Dixon          575    Kumasi    Male   49
# 997      10998    15673900  Wilkinson          520     Bolga  Female   74
# 998      10999    15581432     Oatley          675     Accra    Male   23
# 999      11000    15669645      Tyler          684     Bolga    Male   46
#
#      Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0         1       0.00              1          0               1
# 1         4       0.00              1          0               1
# 2         7       0.00              2          1               0
# 3         4  173255.48              1          1               1
# 4        10  109291.36              1          1               1
# ..      ...        ...            ...        ...             ...
# 995      10  118306.79              1          1               0
# 996       2  136822.70              1          1               0
# 997       4       0.00              1          0               0
# 998       8       0.00              2          0               0
# 999      10       0.00              2          1               0
#
#      EstimatedSalary  Exited
# 0           20443.08       0
# 1            4045.90       0
# 2          128838.67       0
# 3           81293.10       0
# 4          187593.15       0
# ..               ...     ...
# 995         26493.05       0
# 996          2487.74       0
# 997         26742.92       0
# 998        162342.21       0
# 999        188772.98       0
#
# [1000 rows x 14 columns]>

# %% [markdown]
# ### We want to introduce dummy variables to replace our text fields

# %%
gender=pd.get_dummies(test["Gender"],drop_first=True)

# %%
geography=pd.get_dummies(test["Geography"],drop_first=True)

# %%
test=pd.concat([test,gender,geography],axis=1)

# %%
test.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0      10001    15798485    Copley          565     Bolga    Male   31
# 1      10002    15588959     T'ang          569     Bolga    Male   34
# 2      10003    15624896        Ku          669     Bolga  Female   20
# 3      10004    15639629  McConnan          694     Bolga    Male   39
# 4      10005    15638852     Ts'ui          504     Accra    Male   28
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       1       0.00              1          0               1
# 1       4       0.00              1          0               1
# 2       7       0.00              2          1               0
# 3       4  173255.48              1          1               1
# 4      10  109291.36              1          1               1
#
#    EstimatedSalary  Exited  Male  Bolga  Kumasi
# 0         20443.08       0     1      1       0
# 1          4045.90       0     1      1       0
# 2        128838.67       0     0      1       0
# 3         81293.10       0     1      1       0
# 4        187593.15       0     1      0       0

# %%
X=test.drop("Exited",axis=1)
y=test["Exited"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel=LogisticRegression()

# %% [markdown]
# ### Let's drop all columns that will not help us in our analysis

# %%
test.drop(["Geography"],axis=1,inplace=True)
test.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Gender  Age  Tenure  \
# 0      10001    15798485    Copley          565    Male   31       1
# 1      10002    15588959     T'ang          569    Male   34       4
# 2      10003    15624896        Ku          669  Female   20       7
# 3      10004    15639629  McConnan          694    Male   39       4
# 4      10005    15638852     Ts'ui          504    Male   28      10
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          0               1         20443.08
# 1       0.00              1          0               1          4045.90
# 2       0.00              2          1               0        128838.67
# 3  173255.48              1          1               1         81293.10
# 4  109291.36              1          1               1        187593.15
#
#    Exited  Male  Bolga  Kumasi
# 0       0     1      1       0
# 1       0     1      1       0
# 2       0     0      1       0
# 3       0     1      1       0
# 4       0     1      0       0

# %%
test.drop(["RowNumber","CustomerId","Surname","Gender"],axis=1,inplace=True)
test.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          565   31       1       0.00              1          0
# 1          569   34       4       0.00              1          0
# 2          669   20       7       0.00              2          1
# 3          694   39       4  173255.48              1          1
# 4          504   28      10  109291.36              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Male  Bolga  Kumasi
# 0               1         20443.08       0     1      1       0
# 1               1          4045.90       0     1      1       0
# 2               0        128838.67       0     0      1       0
# 3               1         81293.10       0     1      1       0
# 4               1        187593.15       0     1      0       0

# %%
test.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          565   31       1       0.00              1          0
# 1          569   34       4       0.00              1          0
# 2          669   20       7       0.00              2          1
# 3          694   39       4  173255.48              1          1
# 4          504   28      10  109291.36              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Male  Bolga  Kumasi
# 0               1         20443.08       0     1      1       0
# 1               1          4045.90       0     1      1       0
# 2               0        128838.67       0     0      1       0
# 3               1         81293.10       0     1      1       0
# 4               1        187593.15       0     1      0       0

# %%
logmodel.fit(X_test,y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-6ae5e3dee5c0> in <module>
# ----> 1 logmodel.fit(X_test,y_test)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1530
#    1531         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1532                          accept_large_sparse=solver != 'liblinear')
#    1533         check_classification_targets(y)
#    1534         self.classes_ = np.unique(y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     717                     ensure_min_features=ensure_min_features,
#     718                     warn_on_dtype=warn_on_dtype,
# --> 719                     estimator=estimator)
#     720     if multi_output:
#     721         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     494             try:
#     495                 warnings.simplefilter('error', ComplexWarning)
# --> 496                 array = np.asarray(array, dtype=dtype, order=order)
#     497             except ComplexWarning:
#     498                 raise ValueError("Complex data not supported\n"
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'Female'
